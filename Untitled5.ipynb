# %% [markdown]
# <a href="https://colab.research.google.com/github/ismichairunisa/tugas-mandiri-praktikum-4/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Ismi Chairunisa
# Nim : 230705218
# Mk : Kecerdasan buatan

# %%
import re

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import tensorflow as tf

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.utils import class_weight

# %%
from sklearn.metrics import confusion_matrix

# %%
from nltk.tokenize import word_tokenize

# %%
from keras.preprocessing import sequence

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
from keras.preprocessing import sequence

# %%
from keras.layers import Input, Dense, LSTM, Dropout, concatenate

# %%
from tensorflow.keras.layers import Embedding

# %%
from keras.utils import plot_model

# %%
df = pd.read_csv('/content/all_agree.csv')

# %%
df.head()
# Out:
#                                                title  ... label_score
# 0  Masuk Radar Pilwalkot Medan, Menantu Jokowi Be...  ...           0
# 1  Malaysia Sudutkan RI: Isu Kabut Asap hingga In...  ...           0
# 2  Viral! Driver Ojol di Bekasi Antar Pesanan Mak...  ...           1
# 3  Kemensos Salurkan Rp 7,3 M bagi Korban Kerusuh...  ...           0
# 4  MPR: Amandemen UUD 1945 Tak Akan Melebar ke Ma...  ...           0
#
# [5 rows x 3 columns]

# %%
df['label_score'].value_counts()
# Out:
# label_score
# 0    5297
# 1    3316
# Name: count, dtype: int64

# %%
def find_punc(x, punc):
  count = 0
  for char in x:
      if char == punc:
          count += 1
  return count

# %%
df['ccount'] = df['title'].apply(lambda x: find_punc(x, ','))

# %%
df['klctop_count'] = df['title'].apply(lambda x: find_punc(x, '.'))

# %%
df['excl_mark_count'] = df['title'].apply(lambda x: find_punc(x, '!'))

# %%
df['que_mark_count'] = df['title'].apply(lambda x: find_punc(x, '?'))

# %%
df['col_count'] = df['title'].apply(lambda x: find_punc(x, ':'))

# %%
df['semi_col_count'] = df['title'].apply(lambda x: find_punc(x, ';'))

# %%
df['sq_col_count'] = df['title'].apply(lambda x: find_punc(x, "'"))

# %%
df.shape
# Out:
# (8613, 10)

# %%
from numpy._core.defchararray import count
def find_uppercase(x):
    count = 0
    for char in x:
        if char.isupper():
            count += 1
    return count

def find_lowercase(x):
    count = 0
    for char in x:
      if char.islower():
        count += 1
    return count

def find_number(x):
  return len(re.findall('[0-9]', x))

# %%
df['uppercase_count'] = df['title'].apply(find_uppercase)

# %%
df['lowercase_count'] = df['title'].apply(find_lowercase)

# %%
def find_number(x):
  import re
  return len(re.findall('[0-9]', x))

df['number_count'] = df['title'].apply(find_number)

# %%
df.shape
# Out:
# (8613, 13)

# %%
def clean(text):
    # lowering letters
    text = text.lower()
    # Removing punctuations
    text = re.sub('[, .!?:; \]' '', text)
    # Tokenization
    word_tokens = word_tokenize(text)
    # joining words
    text = (''.join(word_tokens))
    return text
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\]'
# <>:5: SyntaxWarning: invalid escape sequence '\]'
# /tmp/ipykernel_11419/809765806.py:5: SyntaxWarning: invalid escape sequence '\]'
#   text = re.sub('[, .!?:; \]' '', text)

# %%
import nltk
nltk.download('punkt_tab', quiet=True)

def clean(text):
    # lowering letters
    text = text.lower()
    # Removing punctuations
    text = re.sub(r'[, .!?:; \']', '', text)
    # Tokenization
    word_tokens = word_tokenize(text)
    # joining words
    text = (''.join(word_tokens))
    return text

df['cleaned_title'] = df['title'].apply(clean)

# %%
df[['title', 'cleaned_title']]
# Out:
#                                                   title                                      cleaned_title
# 0     Masuk Radar Pilwalkot Medan, Menantu Jokowi Be...  masukradarpilwalkotmedanmenantujokowibertemudp...
# 1     Malaysia Sudutkan RI: Isu Kabut Asap hingga In...     malaysiasudutkanriisukabutasaphinggainvasibabi
# 2     Viral! Driver Ojol di Bekasi Antar Pesanan Mak...  viraldriverojoldibekasiantarpesananmakananpaka...
# 3     Kemensos Salurkan Rp 7,3 M bagi Korban Kerusuh...  kemensossalurkanrp73mbagikorbankerusuhansosial...
# 4     MPR: Amandemen UUD 1945 Tak Akan Melebar ke Ma...       mpramandemenuud1945takakanmelebarkemana-mana
# ...                                                 ...                                                ...
# 8608  Twice Rilis Teaser MV 'Feel Special' Jelang Co...  twicerilisteasermvfeelspecialjelangcomebackkon...
# 8609   Asap Karhutla Riau Mulai Merambah Ke Nias, BM...  asapkarhutlariaumulaimerambahkeniasbmkgimbauwa...
# 8610  Tolak RUU Pertanahan, Ribuan Petani Siap Gelar...  tolakruupertanahanribuanpetanisiapgelaraksidii...
# 8611  Ada Niat Tambah Momongan Tanpa Ikut Program Ha...  adaniattambahmomongantanpaikutprogramhamilfedi...
# 8612   TXT Akan Segera Comeback, Soobin Akui Gatal I...  txtakansegeracomebacksoobinakuigatalinginpamer...
#
# [8613 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['title', 'label', 'label_score', 'ccount', 'klctop_count',
#        'excl_mark_count', 'que_mark_count', 'col_count', 'semi_col_count',
#        'sq_col_count', 'uppercase_count', 'lowercase_count', 'number_count',
#        'cleaned_title'],
#       dtype='object')

# %%
x = df.iloc[ :, 3:]
y = df.iloc[ :, 2]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=77)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (6890, 11)
# (1723, 11)

# %%
x_train_title = x_train['cleaned_title']
x_test_title = x_test['cleaned_title']

x_train_punc = x_train.drop('cleaned_title', axis=1)
x_test_punc = x_test.drop('cleaned_title', axis=1)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train['cleaned_title'])

x_train_title = tokenizer.texts_to_sequences(x_train['cleaned_title'])
x_test_title = tokenizer.texts_to_sequences(x_test['cleaned_title'])

# %%
tokenizer.word_index
# Out:
# {'gara': 1,
#  'timnasu': 2,
#  'garaini': 3,
#  '0': 4,
#  '1': 5,
#  'undang': 6,
#  'timnasindonesiau': 7,
#  '16': 8,
#  'surabayamenggugat': 9,
#  '2020': 10,
#  '3': 11,
#  'cukainaik23': 12,
#  'hati': 13,
#  'topikpagi': 14,
#  'pdi': 15,
#  'siap': 16,
#  'hutke': 17,
#  'diawasidihongkongaktivisjoshuawongterbangkeberlin': 18,
#  'anak': 19,
#  'maruf': 20,
#  'x': 21,
#  'hatta': 22,
#  'zodiakmingguan16': 23,
#  '2019': 24,
#  '162020': 25,
#  'pemerintah': 26,
#  'leeminjung': 27,
#  'habisan': 28,
#  'luka': 29,
#  'tahundepanadakebijakancukaibaruapasajaisinya': 30,
#  'kejang': 31,
#  'garahalini': 32,
#  'junu': 33,
#  'cerai': 34,
#  'demokratsiapbantupemerintahanjokowi': 35,
#  'emak': 36,
#  'timorleste': 37,
#  'jadwalbolaakhirpekanligainggrisligaspanyolligaitalia': 38,
#  'gram': 39,
#  '11': 40,
#  'ksditunda': 41,
#  'videodetik': 42,
#  'aksi': 43,
#  'undangkpk': 44,
#  'pembangunansekolahindonesia': 45,
#  'madiun': 46,
#  'blak': 47,
#  'usd': 48,
#  'coba': 49,
#  'kis': 50,
#  'kemkominfososialisasikanmanfaatbantuansosialkepadakpmbpnt': 51,
#  'pkh': 52,
#  '20': 53,
#  'marcus': 54,
#  'indonesiamampupenuhiproteinhewanidalamnegeri': 55,
#  'empatmahasiswaindonesiadiaustraliapernahbunuhdiriapayangbisadicegah': 56,
#  'trick': 57,
#  'indonesiadermawan': 58,
#  '7k': 59,
#  'asean': 60,
#  'previewtimnasu': 61,
#  'fakta': 62,
#  'rizki': 63,
#  '2023': 64,
#  'besaran': 65,
#  'industriasuransioptimistiskembangkanpasardenganjkn': 66,
#  'faktalengkapproducex101yangperlukamutahu': 67,
#  'jadwalsiaranlangsungtimnasindonesiavsthailanddikualifikasipialadunia2022': 68,
#  'manfarfromhome': 69,
#  'jadwalmuvsleicestercitydiligainggrissiaranlangsungtelevisi': 70,
#  'peringatitahunbaruislambanyuwangikembaligelarfestivalmuharam': 71,
#  'viralemak': 72,
#  'warni': 73,
#  '2': 74,
#  'sudahdikafanibangkitlagiternyatapura': 75,
#  'puramatikarenabanyakutang': 76,
#  'ketemumarshandaraffiahmaddibuatsalahtingkah': 77,
#  'lagipestaganjadigrebekpolisipemudainingompoldicelana': 78,
#  'solskjaerdanieljamesmasihbisalebihbaguslagi': 79,
#  'gantikanjohnnyplatetaufikbasariditunjukjadiketuafraksinasdemmpr': 80,
#  'asapindonesiamulaiganggurodaekonomimalaysia': 81,
#  'ojekonlinetolakgabungdemoburuhkarenaalasanini': 82,
#  'ambondiguncangsejumlahgempadalamsemalam': 83,
#  'rayakanulangtahundufanajak1500anakyatimmainbersama': 84,
#  'dapatjatahwamenprojonggakjadibubardanmalahpujiprabowo': 85,
#  'pembalapaustraliaterjatuhtimindonesiajuaraietapeiitourdesiak': 86,
#  'maindikandangborneofcmaduraunitedpunyatargetini': 87,
#  'kabutasapmenebalpenerbanganlokaldilinggariaudibatalkan': 88,
#  'giselbantahtularidugemliaraurelcuekminum': 89,
#  'minumpamerkakinyilangseksi': 90,
#  'munculdigeekbenchgooglepixel4xl5gpunyaram8gbdansd855': 91,
#  'pernahdiajaktidurbarengdivilahinggahamilbibiakhirnyapolisikanpakkades': 92,
#  'pkbtidaksiapkanpenggantiimamnahrawi': 93,
#  'proyektollayangjakarta': 94,
#  'cikampekiitargetrampungakhirseptember': 95,
#  'kyaicholilprogrampetanimilenialhidupkanmentalsantri': 96,
#  'pesertabpjskesehatandiperkirakanbanyakyangpindahkekelaslebihrendah': 97,
#  'twicebeberrahasiatetapsoliddanberikabarsoalkondisimina': 98,
#  'mengenalnovianapengamencantikwisudawanterbaikdiuniversitasairlangga': 99,
#  'festivalgarisimaginerdigelarakhirpekanini': 100,
#  'kuasahukummintapemanggilanketuaumumfpisebagaisaksikasusmakardijadwalulang': 101,
#  'barbiekumalasariakuipunyasuarajazzycumabisadinikmatiyangbermusikalitas': 244,
#  'alasansuzukioptimistispenjualansemesterii2019membaik': 245,
#  'keluargakorbanpengeroyokanpolisimemintaperlindunganhukum': 246,
#  '10000orangdiwamenatelahmendaftaruntukdievakuasiusaikerusuhan': 247,
#  'pesertamagangdapatkarpetmerahjadipegawaipln': 248,
#  'beginijadinyaketikateslamodel3dimodifsuperceper': 249,
#  'anggotabpkakanditetapkanusaiujikelayakanterakhirselasa': 250,
#  '99namacintabukanfilmreligimeskimengambillatarkehidupanpesantren': 251,
#  'kuildithailandsembunyikanpuluhanbangkaiharimau': 252,
#  'tidaktakutgagal4zodiakinisukaambilrisikobesar': 253,
#  'beredarvideog': 254,
#  'dragonbigbangclubbingsambilmerokokdanmabuk': 255,
#  'mabukan': 256,
#  'aparatkembalisiagadijlgatsudekatgedungdprsiangini': 257,
#  'sandradewibikinirikarenatetapcantikdansingsetusaimelahirkan': 258,
#  'manchestercitypunyaskuattermahaldieropa': 259,
#  'akhirnyabesokjokowituruntemuiperwakilanmahasiswa': 260,
#  'kemarauwargacisaruasempatkesulitanmandikanjenazah': 261,
#  'alasanpemudapartaigolkardiymintawalikotayogyakartamengundurkandiri': 262,
#  'trumpkesepakatanperdaganganchinabisatercapaisaatpilpresas': 263,
#  'mantangubernurpapuabaratabrahamatururimeninggal': 264,
#  'andretaulanybeliharleydavidsonsportstersehargarp400': 265,
#  'anjutasetelahnabungselama25tahun': 266,
#  'plndorongpenggunaankendaraanlistriklewatkarnavaljakartalangitbiru': 267,
#  'beginiartinamaanakkeduasandradewi': 268,
#  'ada941pelanggarandiharipertamaperluasanganjilgenap': 269,
#  'thareqhabibiekesehatanbapakmulaistabil': 270,
#  'asusrilisduolaptopvivobookdenganbingkailayartipis': 271,
#  'pengembangdatabaseopensourcepostgresqlse': 272,
#  'asiaberkumpuldibali': 273,
#  'pro': 274,
#  'kontrapemindahanibukotabaruindonesiakekalimantanluhutkalaugakmaukesurgaaja': 275,
#  'setelahsuksesdiduniahiburanadlyfairuzjualankopi': 276,
#  'dampakkabutasaplionairgroupbatalkan21penerbangan': 277,
#  'viralselfiedimakambjhabibiebagaimanahukumnyadalamislam': 278,
#  'afghanistanserukantalibanterimagencatansenjata': 279,
#  'kondisiudarasemakinmemburuksekolahdidharmasrayadiliburkan3hari': 280,
#  'finiske': 281,
#  '11dimotogpsanmarinozarcocukuppuas': 282,
#  'terungkapcarakelvinmembakarmobilberisimayatpupungdandanaauliasiapkan8botolbensin': 283,
#  'transaksiimx2019ditargetkanlebihdarirp3miliar': 284,
#  'polisidalamipenyebarpesanberantaiyangajakpelajardemodimakassar': 285,
#  'rayakanharijadisavasagandengaeonstore': 286,
#  'kitkatgantikemasanplastikdengankertasorigami': 287,
#  'puanindustrispadapattingkatkanperekonomianlokal': 288,
#  'anggarankementerianpuprtahun2020disetujuirp12021triliun': 289,
#  'soalrevisiuukpkrelawannilailangkahjokowitepat': 290,
#  'viralayahmarahianaknyayangikutdemotuaiprodankontra': 845,
#  'bajakahantaraobatdanracunsertakeikhlasanwargaibukotabaruindonesiamemberikannyagratis': 846,
#  'suzypostingekspresiseriusdivagabondmalahditanyasoalresep': 847,
#  'hincasbymintakaderpdpastikanpemerintahanjadilebihbaik': 848,
#  'kasussuapimporikankpkcegah2orangkeluarnegeri': 849,
#  'kivlanzenajukanpermohonanizinberobatdenganterbatuk': 850,
#  'batuk': 851,
#  'jikaasingingelarperundinganpelucutansenjatanukliriniyangdimintakoreautara': 852,
#  'livestreamingtvonlineindosiarpersijajakartavsbaliuniteddiliga12019aksesdisini': 853,
#  '4faktadibalikperhelatanbalkonjazzfestival2019': 854,
#  'lagunyadiviralkandutasheilaon7beginitanggapanlangitsore': 855,
#  '8pasanganzodiakyanghubungannyabertahanlamavirgodancapricornterciptasatusamalain': 856,
#  'cabulibocahenamtahunpedagangsusukelilingdibekasidiringkus': 857,
#  'taufikhidayatungkappesanbjhabibieketimpialathomas1998': 858,
#  'iphone11prodenganwarnaemassepipembeli': 859,
#  'warnarambutlagihitsdiinstagramcobayuk': 860,
#  'malaysiaberencanatidakpenjarakanpenggunanarkoba': 861,
#  'bersiaplawanbarcelonavalenciajustrupecatpelatihmarcelino': 862,
#  'imporricapaiusd142miliarturun15': 863,
#  'dishubdkiperluasanganjilgenapharipertamaperbaikikualitasudara': 864,
#  'tayangmalaminikamis19september2019aksibrucewilisdifilmviceditranstvpukul2300wib': 865,
#  'mantandirutpetraljaditersangkakorupsi': 866,
#  '5pilihanolahragasaathamilmudajalankakihinggapilates': 867,
#  '41kaderperindosumutlolosparlemensekjendppingatkanjangankorupsi': 868,
#  'dprusuldewanpengawaskpktakdipilihpemerintah': 869,
#  'pgiprihatinupayapelemahankpkiniaspirasinya': 870,
#  'wanitadengantubuhberisiterbuktibikinprialebihbahagia': 871,
#  'gyuriekskaradiam': 872,
#  'diampacaribrondongtajirintipfoto': 873,
#  'fotokencanmereka': 874,
#  'kepadapengusahajokowiingatkanketidakpastianekonomiglobal': 875,
#  'sebabtinggimejaloketjanganlebihdari1meter': 876,
#  'beredarvideopolisiteriakitnidimespatitnialinipenjelasanpolri': 877,
#  'ihsgdibukamenguattipiske6244': 878,
#  '10potretliburandiansastrobersamasuamidan2anaknya': 879,
#  'pangkastengkulaktbbmpertaminarewuluinisiasiprogramjapangmas': 880,
#  'menolakrevisiuukpkkatakapitraamperaitumakar': 881,
#  'crowngroupraihduapenghargaanbergengsidiaustralia': 882,
#  'caripemainesportsberbakatwatonggelarmlbbcompetition': 883,
#  'adachrisyedigoogledoodlehariini': 884,
#  'ekspengamencantikdisurabayainijadiwisudawanterbaikdiunairipk': 885,
#  'nya394': 886,
#  'queendomtanggapikabarsoalpesertabayarsendirisemuabiayapenampilan': 887,
#  'savethechildrenpemerintahabaikananakkorbankabutasap': 888,
#  '9pabriktekstiltutupmenperintakadarevitalisasipermesinan': 889,
#  'megawatiterekamtolaksalamisuryapalohisyaratkanpecahkongsi': 890,
#  'garamimpiburukperempuaninitelancincinpertunangannya': 891,
#  'jeongyeontwicekagetsaattahuchaeryeongitzyternyatatetangganya': 980,
#  'selfiedenganhabibie': 981,
#  'santanhinggadaunpandaninibahanpelengkapjajanantradisional': 982,
#  'teganyapabrikminyakgorengdimedanpecatkaryawanjelanglebaran': 983,
#  'catatanimpresifcristianoronaldokegawangatleticobakalberlanjut': 984,
#  'gubernurjabarperkuatkoordinasidengankabupatendankotadikopdar': 985,
#  'gwpp': 986,
#  '6perampokbersebotembakwargahinggatewasdisumsel': 987,
#  'hadirditmpkalibatawargatimorlestehabibiepahlawansaya': 988,
#  'pertemuanbilateralawalikegiatanmenludihighlevelweeksidangumumpbb': 989,
#  'volvotruckshadirkantrukdengansisteminjeksidilengkapiebs': 990,
#  'kabutasapbikinpenerbangandibanjarmasinterganggu': 991,
#  'perluasanganjilgenapbanyakpelanggardijalangunungsahari': 992,
#  'franklampardinginrekrutpemaininiuntukchelsea': 993,
#  'penurunanpenjualanmobildi2019berdampakkeasuransi': 994,
#  'polritunggulaporanresmiuntuktangkapperetassituskemendagri': 995,
#  'shafadilarangpunyatatowajaholehsaritainijawabansaatdisebuttakpernahsusahcariduit': 996,
#  'asapkarhutlatambahparahjarakpandangdiriau800meter': 997,
#  'sekolahdicrimeamulaiajarkanbahasaukraina': 998,
#  'kembangkansistemtaspengandenglembagapensiunanasnkorsel': 999,
#  'pbpmskhawatirpembinaanatletjatengterganggujikaaudisidjarumberhenti': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index)
vocab_size
# Out:
# 7697

# %%
lengths =[]
for sentence in x_train_title:
    lengths.append(len(sentence))

print('Longest sentence\t:', max(lengths))
print('Average length\t:', np.mean(lengths))
print('Median length\t:', np.median(lengths))
# Out:
# Longest sentence	: 6
# Average length	: 1.1380261248185777
# Median length	: 1.0

# %%
x_train_title = sequence.pad_sequences(x_train_title, maxlen=19)
x_test_title = sequence.pad_sequences(x_test_title, maxlen=19)

# %%
class_weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.array([0,1]), y=y_train.values)
class_weights
# Out:
# array([0.80868545, 1.30988593])

# %%
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: np.float64(0.8086854460093896), 1: np.float64(1.3098859315589353)}

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dropout

tf.random.set_seed(99)

lstm_input = Input(shape=(19,))
lstm = Embedding(input_dim=vocab_size+1, output_dim=100)(lstm_input)
lstm = LSTM(3)(lstm)
lstm = Dropout(rate=0.5)(lstm)
lstm_model = Model(inputs=lstm_input, outputs=lstm)

# %%
print(x_trian_title.shape)
print(x_test_title.shape)
# Out:
# (6890, 19)
# (1723, 19)

# %%
dense_input = Input(shape=(5,))
dense = Dropout(rate=0.5) (dense_input)
dense = Dense(3, activation='sigmoid')(dense)
dense_model = Model(inputs=dense_input, outputs=dense)

# %%
print(x_train_punc.shape)
print(x_test_punc.shape)
# Out:
# (6890, 10)
# (1723, 10)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, LSTM, Dropout, Dense, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

tf.random.set_seed(99)

# Model LSTM
lstm_input = Input(shape=(19,))
lstm = Embedding(input_dim=vocab_size+1, output_dim=100)(lstm_input)
lstm = LSTM(3)(lstm)
lstm = Dropout(rate=0.5)(lstm)
lstm_output = Dense(3, activation='sigmoid')(lstm)
lstm_model = Model(inputs=lstm_input, outputs=lstm_output)

# Model Dense sederhana (contoh)
dense_input = Input(shape=(10,)) # misal input lain dengan 10 fitur
dense = Dense(16, activation='relu')(dense_input) # Changed 'rely' to 'relu'
dense_output = Dense(3, activation='sigmoid')(dense)
dense_model = Model(inputs=dense_input, outputs=dense_output)

# Menggabungkan output kedua model
concat = concatenate([lstm_model.output, dense_model.output]) # Corrected .ouput to .output
concat = Dense(6, activation='sigmoid')(concat)
concat = Dense(1, activation='sigmoid')(concat)

# Model gabungan
model = Model(inputs=[lstm_model.input, dense_model.input], outputs=concat)

# Menampilkan ringkasan model
model.summary()
# Out:
# Model: "functional_123"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_104     │ (None, 19)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_55        │ (None, 19, 100)   │    769,800 │ input_layer_104[… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_55 (LSTM)      │ (None, 3)         │      1,248 │ embedding_55[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_105     │ (None, 10)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_76          │ (None, 3)         │          0 │ lstm_55[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_159 (Dense)   │ (None, 16)        │        176 │ input_layer_105[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_158 (Dense)   │ (None, 3)         │         12 │ dropout_76[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_160 (Dense)   │ (None, 3)         │         51 │ dense_159[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, 6)         │          0 │ dense_158[0][0],  │
# │ (Concatenate)       │                   │            │ dense_160[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_161 (Dense)   │ (None, 6)         │         42 │ concatenate_27[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_162 (Dense)   │ (None, 1)         │          7 │ dense_161[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 771,336 (2.94 MB)
#  Trainable params: 771,336 (2.94 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, LSTM, Dropout, Dense, concatenate
from tensorflow.keras.models import Model

tf.random.set_seed(99)

lstm_input = Input(shape=(19,))
lstm = Embedding(input_dim=vocab_size+1, output_dim=100)(lstm_input)
lstm = LSTM(3)(lstm)
lstm = Dropout(rate=0.5)(lstm)
lstm_output = Dense(3, activation='sigmoid')(lstm)
lstm_model = Model(inputs=lstm_input, outputs=lstm_output)

dense_input = Input(shape=(10,))
dense = Dense(16, activation='sigmoid') (dense_input)
dense = Dense(3, activation='sigmoid')(dense)
dense_model = Model(inputs=dense_input, outputs=dense)

concat = concatenate([lstm_model.output, dense_model.output])
concat = Dense(6, activation='sigmoid')(concat)
concat = Dense(1, activation='sigmoid')(concat)

model = Model(inputs=[lstm_model.input, dense_model.input], outputs=concat)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

import numpy as np
x_train_title = np.random.randint(0, 100, size=(1000, 19))
x_train_punc = np.random.rand(1000, 10)
y_train = np.random.randint(0, 2, size=(1000, 1))

x_test_title = np.random.randint(0, 100, size=(200, 19))
x_test_punc = np.random.rand(200,10) # Corrected to 200 samples
y_test = np.random.randint(0, 2, size=(200, ))

history = model.fit(
    [x_train_title, x_train_punc],
    y_train,
    epochs=4,
    batch_size=64,
    validation_data=([x_test_title, x_test_punc], y_test),
)
# Out:
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4990 - loss: 0.6944 - val_accuracy: 0.5100 - val_loss: 0.6930
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4990 - loss: 0.6934 - val_accuracy: 0.5100 - val_loss: 0.6930
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5060 - loss: 0.6931 - val_accuracy: 0.5350 - val_loss: 0.6932
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5200 - loss: 0.6930 - val_accuracy: 0.4900 - val_loss: 0.6933

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
